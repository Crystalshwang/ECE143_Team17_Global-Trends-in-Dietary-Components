# %% [markdown]
# ## Set Up

# %%
import visualization_all as vs
vis = vs.Visualization()

# %% [markdown]
# ## Radar Chart: Daily Caloric Supply from Macronutrient
# This radar graph shows daily caloric supply from four major nutrient.
# Carbohydrates, fat, and protein derived from plant and animal. Carbohydrates supply the most energy in our diet, around 1700 calories.
# Followed by fat around 600 calories. They are our primary energy source.

# %%
vis.radarChart_for_macronutrient()

# %% [markdown]
# ## Box Plot: Daily Caloric Supply by Food Categories
# This graph shows daily caloric supply by major food categories.
# Data distribution is spanned by time. Cereals and grains have very large interquartile range, meaning caloric supply from carbs varies a lot over time. This means people are getting more and more energy from carbs, effectively getting less and less hungrier. Notice sugar also supplies at lot of calories in our daily diet. This shows people like eat a lot of sweet stuffs.

# %%
vis.boxPlot_for_dailyCaloricSupply()

# %% [markdown]
# ## Line Chart: Fruit, Vegetable, Meat Consumption (China, Russia, USA, India)
# These are the line charts for vegetables, fruits and meat intake over forty years (1961-2013). America has high per capita intake in almost every charts with values all around 100. The reason might be that America has the best economic performance in that time period.
# Another distinct line India (blue), in the chart for meat. It is almost parallel to the x-axis. We thought Indian religious belief might have a strong influence on the daily diet.

# %%
vis.lineChart_for_fruit_vegetable_meat_intake(['fruit', 'vegetable', 'meat'])
# Out:
# fruit
# vegetable
# meat

# %% [markdown]
# ## Bar Plot: Dietary Component for China, Russia, USA, India
# This graph shows the dietary components of China, Russia, USA, and India. It demonstrates what people eat in everyday life. Except Americans, people in other three countries eat a lot of cereals and grains. Nevertheless, Americans consume more oil and fat than people in other three countries.

# %%
vis.barPlot_dietary_component_for_four_countries()

# %% [markdown]
# ## Line Chart: Global Food Consumption
# This chart shows the global food consumption in million tons.
# Carbohydrates has the highest consumption. This includes food like cereal, grains, starch roots.
# Followed by vegetable, fruit.
# Notice meat and seafood has the lowest consumption. We think this is because they are relatively more expensive and harder to harvest comparing to plant based food.

# %%
vis.lineChart_food_consumption()

# %% [markdown]
# ## Line Chart: Global Food Consumption (growth comparison)
# This is the same graph but with all lines starting at the origin.
# Vegetable and fruit consumption starts to grow rapidly around 1990s.
# This is when internet is becoming popular. And we think people start to realize they need to eat more healthy.
# You can see a surge in vegetable and fruit consumption.

# %%
vis.lineChart_food_consumption(start_zero=True)

# %% [markdown]
# ## Interactive Map: Global Vegetable Consumption Trend
# Export a single html file distribution.html in the same directory **(takes about 2 min to run)**

# %%
style=vis.initial_style_pyecharts()
vis.generate_map(style)

# %% [markdown]
# ## Interactive Pie Chart: Diet Composition for China, Russia, USA, India
# Export four html files in the same directory: China.html, United States of America.html, India.html, and Russian Federation.html.

# %%
countries=['China','United States of America','India','Russian Federation']
for i in countries:
    vis.generate_pie(i)
